# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'retina'

from mle_toolbox.utils import load_pkl_object, load_run_log
import matplotlib.pyplot as plt
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pbt_log_path = "../examples/experiments/pbt_log.pkl"

pbt_log = load_pkl_object(pbt_log_path)

# %%
pbt_log = pbt_log.sort_values(["pbt_step_id", "worker_id"])
np.unique(pbt_log.num_updates, return_index=True)
# Out:
# (array([100., 200., 300., 400., 500.]), array([41, 24, 31,  3,  0]))

# %%
pbt_log[pbt_log["worker_id"] == 3]["hyperparams"].tolist()
# Out:
# [{'l_rate': 0.0049180737944024755},
#  {'l_rate': 0.0049180737944024755},
#  {'l_rate': 0.0049180737944024755},
#  {'l_rate': 0.0049180737944024755},
#  {'l_rate': 0.0049180737944024755},
#  {'l_rate': 0.0024869013306374134},
#  {'l_rate': 0.0024869013306374134},
#  {'l_rate': 0.0024869013306374134},
#  {'l_rate': 0.0024869013306374134},
#  {'l_rate': 0.0024869013306374134}]

# %%
pbt_log.shape
# Out:
# (200, 12)

# %%
for i in range(10):
    loss = pbt_log[pbt_log["worker_id"] == i]["performance"].tolist()
    print(loss[-1])
    plt.plot(loss)
plt.ylim(0.05, 0.25)
# Out:
# 0.0938853994011879
# 0.08996070921421051
# 0.09211944043636322
# 0.09839298576116562
# 0.09812627732753754
# 0.09870259463787079
# 0.09473603963851929
# 0.10205129534006119
# 0.09331192821264267
# 0.09159553796052933
# (0.05, 0.25)

# %%
pbt_log
# Out:
#      worker_id  pbt_step_id  num_updates  performance                        hyperparams  copy_bool  copy_from_worker_id  copy_from_pbt_steps  copy_from_num_updates  copy_from_performance                                     copy_from_ckpt              copy_from_hyperparams
# 1            0            0        500.0     0.166202   {'l_rate': 0.003238152774267465}      False                  NaN                  NaN                    NaN                    NaN  experiments/pbt_mnist/21-06-30_worker_0_step_0...   {'l_rate': 0.003238152774267465}
# 0            1            0        500.0     0.178204   {'l_rate': 0.006167246722674341}      False                  NaN                  NaN                    NaN                    NaN  experiments/pbt_mnist/21-06-30_worker_1_step_0...   {'l_rate': 0.006167246722674341}
# ...
