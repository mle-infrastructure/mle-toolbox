# %%
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'retina'

from IPython.display import HTML, Image
import numpy as np

# %%
time_steps = 50
num_lines = 5
grid_size = 10

# %% [markdown]
# # Animate 1D Lines

# %%
from mle_toolbox.visualize import animate_1D_lines
noisy_lines = np.random.normal(size=(time_steps, num_lines))

# %%
animate_1D_lines(noisy_lines, fname="line_anim_1.gif")
Image(url='line_anim_1.gif')
# Out:
# <img src="line_anim_1.gif"/>

# %%
animate_1D_lines(noisy_lines, dt=1, line_labels=[5,6,7,8,9], base_label="Line",
                 ylabel="Value", xlabel="Time",
                 title="Animated Random Numbers", interval=100, fps=10,
                 fname="line_anim_2.gif", direct_save=True)
Image(url='line_anim_2.gif')
# Out:
# <img src="line_anim_2.gif"/>

# %% [markdown]
# # Animate 2D Heatmaps

# %%
from mle_toolbox.visualize import animate_2D_grid
noisy_grid = np.random.normal(size=(time_steps, grid_size, grid_size))

# %%
animate_2D_grid(noisy_grid, fname="grid_anim_1.gif")
Image(url='grid_anim_1.gif')
# Out:
# <img src="grid_anim_1.gif"/>

# %%
animate_2D_grid(noisy_grid, var_name="A Variable", dt=1,
                ylabel="Cool variable", xlabel="Not so cool variable",
                range_y=None, range_x=None, every_nth=1, round_ticks=2,
                vmin=None, vmax=None,
                title="Animated Grid", interval=100, fps=60,
                fname="grid_anim_2.gif", direct_save=True)
Image(url='grid_anim_2.gif')
# Out:
# <img src="grid_anim_2.gif"/>

# %% [markdown]
# # Animate 2D Scatterplot

# %%
from mle_toolbox.visualize import animate_2D_scatter
num_points = 10
num_coords = 2
noisy_points = np.random.normal(size=(time_steps, num_points, num_coords))

# %%
animate_2D_scatter(noisy_points, fname="scatter_anim_1.gif")
Image(url='scatter_anim_1.gif')
# Out:
# <img src="scatter_anim_1.gif"/>

# %%
animate_2D_scatter(data, dt=1,
                   ylabel="y-Axis Label", xlabel="x-Axis Label",
                   title="Animated Scatter", no_axis=False,
                   interval=100, fps=60,
                   fname="scatter_anim_2.gif", direct_save=True)
Image(url='scatter_anim_2.gif')
